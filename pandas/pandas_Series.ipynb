# %% [markdown]
# <a href="https://colab.research.google.com/github/farxod0518/data_science_and_AI_learning/blob/main/pandas/pandas_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas kutubxonasi bilan tanishamiz.

# %% [markdown]
# ## Series malumotlar tuzilmasi.

# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
series1 = Series([3,7,4,9,1]) # bu yerda pandas kutubxonasining Series malumotlar tuzilmasidagi object yaratib oldik.
print(series1)
# Out:
# 0    3
# 1    7
# 2    4
# 3    9
# 4    1
# dtype: int64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series1.values # obyektning faqat qiymatlarini ko'rishimiz mumkin.
# Out:
# array([3, 7, 4, 9, 1])

# %%
series1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
series1[1:4]
# Out:
# 1    7
# 2    4
# 3    9
# dtype: int64

# %%
series2 = Series([9,3,-5,12,-7], index=["a",'b','c','d','e']) # Seriesning pythondagi malumot turlaridan asosiy farqi bunda biz indexlarni o'zimiz kiritishimiz mumkin.

# %%
print(series2)
# Out:
# a     9
# b     3
# c    -5
# d    12
# e    -7
# dtype: int64

# %%
series2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
series2[['e','c','b']]
# Out:
# e   -7
# c   -5
# b    3
# dtype: int64

# %%
series2[series2>1]
# Out:
# a     9
# b     3
# d    12
# dtype: int64

# %%
series2*10
# Out:
# a     90
# b     30
# c    -50
# d    120
# e    -70
# dtype: int64

# %%
np.sqrt(series2)
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# a    3.000000
# b    1.732051
# c         NaN
# d    3.464102
# e         NaN
# dtype: float64

# %% [markdown]
# ## Lugatlar va Serieslar bilan ishlash.

# %%
cars_dic = {'spark':6000,"cobalt":14000,"gentra":15000,'tracker':22000,"onix":20000}

# %%
cars_series = Series(cars_dic) # bu yerda lugatni seriesga aylantirib oldik.
print(cars_series)
# Out:
# spark       6000
# cobalt     14000
# gentra     15000
# tracker    22000
# onix       20000
# dtype: int64

# %%
'cobalt' in cars_series
# Out:
# True

# %%
'malibu' in cars_series
# Out:
# False

# %%
cars_series['tracker']
# Out:
# np.int64(22000)

# %%
model = ['cobalt','onix','BMW','tracker','spark','gentra','mersedes']

# %%
cars2_series = Series(cars_dic, index = model) # bu yerda biz o'zimiz hoxlagan tartibdagi indexli abyekt yaratib oldik.

# %%
cars2_series
# Out:
# cobalt      14000.0
# onix        20000.0
# BMW             NaN
# tracker     22000.0
# spark        6000.0
# gentra      15000.0
# mersedes        NaN
# dtype: float64

# %% [markdown]
# ## series metodlari va parametrlari.

# %%
cars2_series.isnull() # bu metod bizda bo'sh elementlarni true holatda qaytaradi.
# Out:
# cobalt      False
# onix        False
# BMW          True
# tracker     False
# spark       False
# gentra      False
# mersedes     True
# dtype: bool

# %%
cars2_series.notnull() #bu metod mavjuda bo'lmagan elementlarni false holatda qaytaradi.
# Out:
# cobalt       True
# onix         True
# BMW         False
# tracker      True
# spark        True
# gentra       True
# mersedes    False
# dtype: bool

# %%
cars2_series + cars_series # series ustida qo'shish amamlini bajarsak indexlari mos elementlarning qiymatlari qo'shiladi.
# Out:
# BMW             NaN
# cobalt      28000.0
# gentra      30000.0
# mersedes        NaN
# onix        40000.0
# spark       12000.0
# tracker     44000.0
# dtype: float64

# %%
cars_series.name = 'chirchiq avtosalon' # bu yerda seriesga nom berdik.

# %%
cars_series.index.name = 'modellar' # bu yerda series indexlariga umumiy nom berdik.

# %%
cars_series
# Out:
# modellar
# spark       6000
# cobalt     14000
# gentra     15000
# tracker    22000
# onix       20000
# Name: chirchiq avtosalon, dtype: int64

# %%
cars_series.index.name
# Out:
# 'modellar'

# %%
cars_series.index # indexlar
# Out:
# Index(['spark', 'cobalt', 'gentra', 'tracker', 'onix'], dtype='object', name='modellar')

# %%
cars_series.values # qiymatlar
# Out:
# array([ 6000, 14000, 15000, 22000, 20000])

# %%
cars2_series.hasnans # nan qiymat bor bo'lsa true bo'lmasa false qaytaradi.
# Out:
# True

# %%
cars_series.hasnans
# Out:
# False

# %%
cars_series.dtype
# Out:
# dtype('int64')

# %%
cars_series['onix'] = 'mavjud emas'
# Out:
# /tmp/ipykernel_6242/4094028953.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mavjud emas' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   cars_series['onix'] = 'mavjud emas'

# %%
cars_series
# Out:
# modellar
# spark             6000
# cobalt           14000
# gentra           15000
# tracker          22000
# onix       mavjud emas
# Name: chirchiq avtosalon, dtype: object

# %%
cars_series.dtype
# Out:
# dtype('O')

# %%
cars_series.is_unique # qiymatlar takrorlanmas ekanligini tekshiradi.
# Out:
# True

# %%
cars_series.shape # series shaklini aniqlaydi.
# Out:
# (5,)

# %%
cars_series.size # series hajmini aniqlaydi.
# Out:
# 5

# %%
cars_series
# Out:
# modellar
# spark             6000
# cobalt           14000
# gentra           15000
# tracker          22000
# onix       mavjud emas
# Name: chirchiq avtosalon, dtype: object

# %%
cars_series.iloc[2] # elementlarga index tartib raqami bo'yicha murojat qiladi.
# Out:
# 15000

# %%
cars_series.iloc[0]
# Out:
# 6000

# %%
cars_series.iloc[-2:]
# Out:
# modellar
# tracker          22000
# onix       mavjud emas
# Name: chirchiq avtosalon, dtype: object

# %%
cars_series['gentra']
# Out:
# 15000

# %%
cars2_series
# Out:
# cobalt      14000.0
# onix        20000.0
# BMW             NaN
# tracker     22000.0
# spark        6000.0
# gentra      15000.0
# mersedes        NaN
# dtype: float64

# %%
cars2_series.max() # maximum qiymat qaytaradi.
# Out:
# 22000.0

# %%
cars2_series.min()
# Out:
# 6000.0

# %%
cars2_series.mean() # o'rta arifmetik qiymatini aniqlaydi.
# Out:
# np.float64(15400.0)

# %%
namuna = Series()

# %%
namuna
# Out:
# Series([], dtype: object)

# %%
del namuna # to'liq o'chirib tashlash.

# %%
cars_series.drop('onix') # elementlarni o'chirish uchun drop dan foydalanib o'chirib tashladik.

# %%
cars_series = cars_series.astype(float) # malumot turini o'zgartirdik.

# %%
cars_series.dtype
# Out:
# dtype('float64')

# %%
cars_series
# Out:
# modellar
# spark       6000.0
# cobalt     14000.0
# gentra     15000.0
# tracker    22000.0
# Name: chirchiq avtosalon, dtype: float64

# %%
cars_series = cars_series[cars_series>=15000] # qiymati 15000 dan kichik bo'lgan barcha elementlarni o'chirib tashladik.

# %%
cars_series
# Out:
# modellar
# gentra     15000.0
# tracker    22000.0
# Name: chirchiq avtosalon, dtype: float64
