# %% [markdown]
# <a href="https://colab.research.google.com/github/farxod0518/data_science_and_AI_learning/blob/main/pandas/pandas_1_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# # **AMALIYOT**
# ## 3.1 Series va Index

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %%
#@title To'g'ri javob
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2-mashq.** O'zbekiston Respublikasi viloyatlaridan iborat bir o'lchamli Series obyektini yarating

# %%
# Javobni shu yerga yozing
ser = pd.Series(['andijon','buxoro',"farg'ona","jizzax","xorazm","namangan","navoiy","qashqadaryo","qoraqalpog'iston","samarqand","sirdaryo","surxondaryo","toshkent"])
ser
# Out:
# 0              andijon
# 1               buxoro
# 2             farg'ona
# 3               jizzax
# 4               xorazm
# 5             namangan
# 6               navoiy
# 7          qashqadaryo
# 8     qoraqalpog'iston
# 9            samarqand
# 10            sirdaryo
# 11         surxondaryo
# 12            toshkent
# dtype: object

# %%
#@title **To'g'ri javob**
obj = pd.Series(
    [
        "Andijon",
        "Buxoro",
        "Farg'ona",
        "Jizzax",
        "Xorazm",
        "Namangan",
        "Navoiy",
        "Qashqadaryo",
        "Qoraqalpog'iston Respublikasi",
        "Samarqand",
        "Sirdaryo",
        "Surxondaryo",
        "Toshkent",
    ]
)
print(obj)
# Out:
# 0                           Andijon
# 1                            Buxoro
# 2                          Farg'ona
# 3                            Jizzax
# 4                            Xorazm
# 5                          Namangan
# 6                            Navoiy
# 7                       Qashqadaryo
# 8     Qoraqalpog'iston Respublikasi
# 9                         Samarqand
# 10                         Sirdaryo
# 11                      Surxondaryo
# 12                         Toshkent
# dtype: object

# %% [markdown]
# ### **3-mashq.** Yuqorida yaratilgan Series obyektining barcha qiymaltarini chiqaring

# %%
# Javobni shuyerga yozing
ser.values
# Out:
# array(['andijon', 'buxoro', "farg'ona", 'jizzax', 'xorazm', 'namangan',
#        'navoiy', 'qashqadaryo', "qoraqalpog'iston", 'samarqand',
#        'sirdaryo', 'surxondaryo', 'toshkent'], dtype=object)

# %%
# @title **To'g'ri javob**
obj.values
# Out:
# array(['Andijon', 'Buxoro', "Farg'ona", 'Jizzax', 'Xorazm', 'Namangan',
#        'Navoiy', 'Qashqadaryo', "Qoraqalpog'iston Respublikasi",
#        'Samarqand', 'Sirdaryo', 'Surxondaryo', 'Toshkent'], dtype=object)

# %% [markdown]
# ### **4-mashq.** Yuqoridagi Series obyektining eng birinchi qiymatini chiqaring

# %%
# Javobni shuyerga yozing
ser.values[0]
# Out:
# 'andijon'

# %%
# @title **To'g'ri javob**
obj[0]
# Out:
# 'Andijon'

# %% [markdown]
# ### **5-mashq.** Yuqoridagi Series obyektining eng oxirgi qiymatini chiqaring

# %%
# Javobni shuyerga yozing
ser.values[-1]
# Out:
# 'toshkent'

# %%
# @title **To'g'ri javob**
obj[12]
# Out:
# 'Toshkent'

# %% [markdown]
# ### **6-mashq.** Yuqoridagi Series obyekti uzunligini chiqaring

# %%
# Javobni shuyerga yozing
len(ser.values)
# Out:
# 13

# %%
# @title **To'g'ri javob**
obj.size
# Out:
# 13

# %% [markdown]
# ### **7-mashq.** Yuqoridagi Series obyektining o'rtasidan 3 ta qiymat chiqaring

# %%
# Javobni shuyerga yozing
ser[[5,6,7]]
# Out:
# 5       namangan
# 6         navoiy
# 7    qashqadaryo
# dtype: object

# %%
# @title **To'g'ri javob**

obj[[5, 6, 7]]
# Out:
# 5       Namangan
# 6         Navoiy
# 7    Qashqadaryo
# dtype: object

# %% [markdown]
# ### **8-mashq.** Quyidagi Series obyektini yarating.
# **Ahamiyat bering. `Series` obyekti indeksi sifatida viloyatlar nomi ishlatilgan**

# %%
# @title
ind = obj.values
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
obj2 = pd.Series(aholi, index=ind)
print(obj2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/1193905783.py in <cell line: 0>()
#       1 # @title
# ----> 2 ind = obj.values
#       3 aholi = [
#       4     1899000,
#       5     1384700,
#
# NameError: name 'obj' is not defined

# %%
# Javobni shuyerga yozing
ser2 = pd.Series([1899000,1384700,2597000,910500,1200000,1862000,767500,2029000,1200000,2322000,648100,1676000,4450000],index=['andijon','buxoro',"farg'ona","jizzax","xorazm","namangan","navoiy","qashqadaryo","qoraqalpog'iston respublikasi","samarqand","sirdaryo","surxondaryo","toshkent"])
ser2
# Out:
# andijon                          1899000
# buxoro                           1384700
# farg'ona                         2597000
# jizzax                            910500
# xorazm                           1200000
# namangan                         1862000
# navoiy                            767500
# qashqadaryo                      2029000
# qoraqalpog'iston respublikasi    1200000
# samarqand                        2322000
# sirdaryo                          648100
# surxondaryo                      1676000
# toshkent                         4450000
# dtype: int64

# %% [markdown]
# ### **9-mashq.** Yuqoridagi `Series` obyektidan Jizzax, Buxoro va Namangan viloyatlarining aholisini chiqaring

# %%
# Javobni shuyerga yozing
print(ser2[['jizzax','buxoro','namangan']])
# Out:
# jizzax       910500
# buxoro      1384700
# namangan    1862000
# dtype: int64

# %%
# @title **To'g'ri javob**
obj2[["Jizzax", "Buxoro", "Namangan"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/1906801074.py in <cell line: 0>()
#       1 # @title **To'g'ri javob**
# ----> 2 obj2[["Jizzax", "Buxoro", "Namangan"]]
#
# NameError: name 'obj2' is not defined

# %% [markdown]
# ### **10-mashq.** Yuqoridagi `Series` obyektidan aholi soni 1 milliondan kam va ko'p bo'lgan viloyatlarni alohida chiqaring

# %%
# Javobni shuyerga yozing
print("aholisi 1 milliondan ko'p bo'lgan viloyatlar")
print(ser2[ser2>1000000])
print("aholisi 1 milliondan kam bo'lgan viloyatlar")
print(ser2[ser2<1000000])
# Out:
# aholisi 1 milliondan ko'p bo'lgan viloyatlar
# andijon             1899000
# buxoro              1384700
# farg'ona            2597000
# xorazm              1200000
# namangan            1862000
# qashqadaryo         2029000
# qoraqalpog'iston    1200000
# samarqand           2322000
# surxondaryo         1676000
# toshkent            4450000
# dtype: int64
# aholisi 1 milliondan kam bo'lgan viloyatlar
# jizzax      910500
# navoiy      767500
# sirdaryo    648100
# dtype: int64

# %%
# @title **To'g'ri javob**
print("Aholisi 1 milliondan ko'p viloyatlar")
print(obj2[obj2 > 1_000_000])
# Pythonda katta sonlarni yozishda 0 orasini _ bilan ajratish mumkin
# Out:
# Aholisi 1 milliondan ko'p viloyatlar
# Andijon                          1899000
# Buxoro                           1384700
# Farg'ona                         2597000
# Xorazm                           1200000
# Namangan                         1862000
# Qashqadaryo                      2029000
# Qoraqalpog'iston Respublikasi    1200000
# Samarqand                        2322000
# Surxondaryo                      1676000
# Toshkent                         4450000
# dtype: int64

# %%
# @title
print("Aholisi 1 milliondan kam viloyatlar")
print(obj2[obj2 < 1_000_000])
# Out:
# Aholisi 1 milliondan kam viloyatlar
# Jizzax      910500
# Navoiy      767500
# Sirdaryo    648100
# dtype: int64

# %% [markdown]
# ### **11-mashq.** Aholisi 1 milliondan ko'p davlatlar orasida Navoiy viloyati bor/yo'qligini tekshiring

# %%
# Javobni shuyerga yozing
'navoiy' in ser2[ser2>1000000]
# Out:
# False

# %%
# @title **To'g'ri javob**
"Navoiy" in obj2[obj2 > 1_000_000]
# Out:
# False

# %% [markdown]
# ### **12-mashq.** Quyidagi lug'atda viloyatlar va ularning maydonlari berilgan. Lug'atdan yangi `Series` obyektini yarating va unga "Hududlar hajmi" deb nom bering

# %%
dict = {
    "Andijon": 4200,
    "Buxoro": 39400,
    "Farg'ona": 6800,
    "Jizzax": 20500,
    "Xorazm": 6300,
    "Namangan": 7900,
    "Navoiy": 110800,
    "Qashqadaryo": 28400,
    "Qoraqalpog'iston Respublikasi": 160000,
    "Samarqand": 16400,
    "Sirdaryo": 5100,
    "Surxondaryo": 20800,
    "Toshkent": 15300,
}

# %%
# Javobni shuyerga yozing
ser3 = pd.Series(dict)
ser3.name = "hududlar hajmi"
print(ser3)
# Out:
# Andijon                            4200
# Buxoro                            39400
# Farg'ona                           6800
# Jizzax                            20500
# Xorazm                             6300
# Namangan                           7900
# Navoiy                           110800
# Qashqadaryo                       28400
# Qoraqalpog'iston Respublikasi    160000
# Samarqand                         16400
# Sirdaryo                           5100
# Surxondaryo                       20800
# Toshkent                          15300
# Name: hududlar hajmi, dtype: int64

# %%
#@title To'g'ri javob
obj3 = pd.Series(dict)
obj3.name = "Hudular hajmi"
print(obj3)
# Out:
# Andijon                            4200
# Buxoro                            39400
# Farg'ona                           6800
# Jizzax                            20500
# Xorazm                             6300
# Namangan                           7900
# Navoiy                           110800
# Qashqadaryo                       28400
# Qoraqalpog'iston Respublikasi    160000
# Samarqand                         16400
# Sirdaryo                           5100
# Surxondaryo                       20800
# Toshkent                          15300
# Name: Hudular hajmi, dtype: int64

# %% [markdown]
# ### **13-mashq.** Yuqoridagi `Series` obyektidan hududi eng katta va eng kichik elementlarni chiqaring

# %%
# Javobni shuyerga yozing
print(f"eng katta hudud: {ser3.idxmax()}")
print(f"eng kichik hudud: {ser3.idxmin()}")
# Out:
# eng katta hudud: Qoraqalpog'iston Respublikasi
# eng kichik hudud: Andijon

# %%
#@title To'g'ri javob
print(f"Eng katta hudud: {obj3.idxmax()}")
print(f"Eng kichik hudud: {obj3.idxmin()}")
# Out:
# Eng katta hudud: Qoraqalpog'iston Respublikasi
# Eng kichik hudud: Andijon

# %% [markdown]
# ### **14-mashq.** Yuqoridagi eng katta va eng kichik hududlar aholisi sonini chiqaring

# %%
# Javobni shuyerga yozing
print(f"{ser3.idxmax()} aholisi: {ser2[ser3.idxmax().lower()]}")
print(f"{ser3.idxmin()} aholisi: {ser2[ser3.idxmin().lower()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi: 1200000
# Andijon aholisi: 1899000

# %%
#@title To'g'ri javob
print(f"{obj3.idxmax()} aholisi {obj2[obj3.idxmax()]}")
print(f"{obj3.idxmin()} aholisi {obj2[obj3.idxmin()]}")
# Out:
# Qoraqalpog'iston Respublikasi aholisi 1200000
# Andijon aholisi 1899000

# %% [markdown]
# ### **15-mashq**. Yuqoridagi hudulardan O'zbekiston Respublikasi hududini hisoblang

# %%
# Javobni shuyerga yozing
sum(ser3)
# Out:
# 441900

# %%
#@title To'g'ri javob
sum(obj3)
# Out:
# 441900

# %% [markdown]
# ### **16-mashq.** Aholisi eng ko'p va eng kam hududlarning hajmini va aholi sonini chiqaring

# %%
# Javobni shuyerga yozing
print(f"{ser2.idxmax()} hududi {ser3[ser2.idxmax().title()]}kv.km, aholisi {ser2.max()}")
print(f"{ser2.idxmin()} hududi {ser3[ser2.idxmin().title()]}kv.km, aholisi {ser2.min()}")
# Out:
# toshkent hududi 15300kv.km, aholisi 4450000
# sirdaryo hududi 5100kv.km, aholisi 648100

# %%
#@title To'g'ri javob
print(f"{obj2.idxmax()} hududi {obj3[obj2.idxmax()]}kv.km, aholisi {obj2[obj2.idxmax()]}")
print(f"{obj2.idxmin()} hududi {obj3[obj2.idxmin()]}kv.km, aholisi {obj2[obj2.idxmin()]}")
# Out:
# Toshkent hududi 15300kv.km, aholisi 4450000
# Sirdaryo hududi 5100kv.km, aholisi 648100

# %% [markdown]
# ### **17-mashq.** Yuqoridagi ikki obyektdan foydalangan holda O'zbekiston respublikasi tarkibidagi hududlarni avval aholi soni bo'yicha, keyin esa hajmi bo'yicha tartiblab chiqaring

# %%
# Javobni shuyerga yozing
print("hududlar hajmi bo'yicha tartiblash")
print(ser3.sort_values())
print("aholi soni bo'yicha tartiblash")
print(ser2.sort_values())
# Out:
# hududlar hajmi bo'yicha tartiblash
# Andijon                            4200
# Sirdaryo                           5100
# Xorazm                             6300
# Farg'ona                           6800
# Namangan                           7900
# Toshkent                          15300
# Samarqand                         16400
# Jizzax                            20500
# Surxondaryo                       20800
# Qashqadaryo                       28400
# Buxoro                            39400
# Navoiy                           110800
# Qoraqalpog'iston Respublikasi    160000
# Name: hududlar hajmi, dtype: int64
# aholi soni bo'yicha tartiblash
# sirdaryo                          648100
# navoiy                            767500
# jizzax                            910500
# xorazm                           1200000
# qoraqalpog'iston respublikasi    1200000
# buxoro                           1384700
# surxondaryo                      1676000
# namangan                         1862000
# andijon                          1899000
# qashqadaryo                      2029000
# samarqand                        2322000
# farg'ona                         2597000
# toshkent                         4450000
# dtype: int64

# %%
#@title To'g'ri javob
print("Hududlar hajmi bo'yicha tartiblash")
obj3.sort_values()
# Out:
# Hududlar hajmi bo'yicha tartiblash
# Andijon                            4200
# Sirdaryo                           5100
# Xorazm                             6300
# Farg'ona                           6800
# Namangan                           7900
# Toshkent                          15300
# Samarqand                         16400
# Jizzax                            20500
# Surxondaryo                       20800
# Qashqadaryo                       28400
# Buxoro                            39400
# Navoiy                           110800
# Qoraqalpog'iston Respublikasi    160000
# Name: Hudular hajmi, dtype: int64

# %%
#@title To'g'ri javob
print("Aholi soni bo'yicha tartiblash")
obj2.sort_values()
# Out:
# Aholi soni bo'yicha tartiblash
# Sirdaryo                          648100
# Navoiy                            767500
# Jizzax                            910500
# Xorazm                           1200000
# Qoraqalpog'iston Respublikasi    1200000
# Buxoro                           1384700
# Surxondaryo                      1676000
# Namangan                         1862000
# Andijon                          1899000
# Qashqadaryo                      2029000
# Samarqand                        2322000
# Farg'ona                         2597000
# Toshkent                         4450000
# dtype: int64
